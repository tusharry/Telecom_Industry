# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
x = pd.read_csv(r'C:\Users\ADMIN\Desktop\CODES\telecom_industry.csv')
x.head()
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1869  7010-BRBUU    Male              0     Yes        Yes      72
# 1        4528  9688-YGXVR  Female              0      No         No      44
# 2        6344  9286-DOJGF  Female              1     Yes         No      38
# 3        6739  6994-KERXL    Male              0      No         No       4
# 4         432  2181-UAESM    Male              0      No         No       2
#
#   PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# 0          Yes           Yes              No  ...  No internet service
# 1          Yes            No     Fiber optic  ...                  Yes
# 2          Yes           Yes     Fiber optic  ...                   No
# 3          Yes            No             DSL  ...                   No
# 4          Yes            No             DSL  ...                  Yes
#
#            TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
x.shape
# Out:
# (5986, 22)

# %%
x.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
x.drop(['Unnamed: 0', 'customerID'], axis = 'columns', inplace = True)

# %%
x.head(2)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      72          Yes
# 1  Female              0      No         No      44          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes              No  No internet service  No internet service
# 1            No     Fiber optic                   No                  Yes
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# 1                  Yes                   No                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0  No internet service        Two year               No
# 1                   No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Credit card (automatic)           24.10      1734.65    No
# ...

# %%
x['PaymentMethod'].value_counts()
# Out:
# Electronic check             2006
# Mailed check                 1369
# Bank transfer (automatic)    1308
# Credit card (automatic)      1303
# Name: PaymentMethod, dtype: int64

# %%
plt.figure (figsize = (7, 7))
plt.hist(x['PaymentMethod'], color = 'red')
plt.show()

# %%
x.head(2)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      72          Yes
# 1  Female              0      No         No      44          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes              No  No internet service  No internet service
# 1            No     Fiber optic                   No                  Yes
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# 1                  Yes                   No                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0  No internet service        Two year               No
# 1                   No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Credit card (automatic)           24.10      1734.65    No
# ...

# %%
plt.figure(figsize = (5, 5))
plt.pie (x['gender'].value_counts(), labels = x['gender'].value_counts().keys(), autopct = '%1f%%', startangle = 90)
plt.title('GENDER')
plt.show()

plt.figure(figsize = (5, 5))
plt.pie (x['SeniorCitizen'].value_counts(), labels = ['Retired','Not Retired'], autopct = '%1f%%', startangle = 90)
plt.title('Senior Citizen')
plt.show()

# %%
plt.figure(figsize = (5, 5))
plt.pie(x['Churn'].value_counts(), labels = ['No', 'Yes'], autopct = '%1f%%', startangle = 90)
plt.title('Churn')
plt.show()

# %%
plt.figure(figsize = (5, 5))
sns.countplot(x.gender, hue = x.Churn)
plt.show()

plt.figure(figsize = (5, 5))
sns.countplot(x.SeniorCitizen, hue = x.Churn)
plt.show()
# Out:
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (10, 10))
sns.histplot(x['tenure'], bins = 70, kde = True, color = 'red')
plt.grid()
plt.show()

# %%
x.nunique()
# Out:
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1526
# TotalCharges        5611
# Churn                  2
# dtype: int64

# %%
for i in x.columns:
    print('Unique values in', i, 'are:', x[i].unique())
    print(''*100)
# Out:
# Unique values in gender are: ['Male' 'Female']
#
# Unique values in SeniorCitizen are: [0 1]
#
# Unique values in Partner are: ['Yes' 'No']
#
# Unique values in Dependents are: ['Yes' 'No']
#
# Unique values in tenure are: [72 44 38  4  2 70 33  1 39 55 52 30 60 50 32 51 69 42 14 62  5 63 67 40
#  65 16 46 11 49 68 10 53 54 15  3 71  8 64 57 20 26 31  7 35  6 13 23  9
#  45 17 34 58 12 25 28 29 43 19 41 37 27 22 24 18 56 66 59 48 47 61 21  0
#  36]
#
# Unique values in PhoneService are: ['Yes' 'No']
#
# Unique values in MultipleLines are: ['Yes' 'No' 'No phone service']
#
# Unique values in InternetService are: ['No' 'Fiber optic' 'DSL']
#
# Unique values in OnlineSecurity are: ['No internet service' 'No' 'Yes']
#
# Unique values in OnlineBackup are: ['No internet service' 'Yes' 'No']
#
# Unique values in DeviceProtection are: ['No internet service' 'Yes' 'No']
#
# Unique values in TechSupport are: ['No internet service' 'No' 'Yes']
#
# ...

# %%
x = x.replace('Female', 0)
x = x.replace('Male', 1)
x = x.replace('No', 0)
x = x.replace('Yes', 1)
x = x.replace('No phone service', 2)
x = x.replace('No internet service', 2)
x = x.replace('Two year', 24)
x = x.replace('Month-to-month', 1)
x = x.replace('One year', 12)
x = x.replace('Fiber optic', 1)
x = x.replace('DSL', 2)
x = x.replace('Credit card (automatic)', 0)
x = x.replace('Bank transfer (automatic)', 1)
x = x.replace('Electronic check', 2)
x = x.replace('Mailed check', 3)

# %%
for i in x.columns:
    print('Unique values in', i, 'are:', x[i].unique())
    print(''*100)
# Out:
# Unique values in gender are: [1 0]
#
# Unique values in SeniorCitizen are: [0 1]
#
# Unique values in Partner are: [1 0]
#
# Unique values in Dependents are: [1 0]
#
# Unique values in tenure are: [72 44 38  4  2 70 33  1 39 55 52 30 60 50 32 51 69 42 14 62  5 63 67 40
#  65 16 46 11 49 68 10 53 54 15  3 71  8 64 57 20 26 31  7 35  6 13 23  9
#  45 17 34 58 12 25 28 29 43 19 41 37 27 22 24 18 56 66 59 48 47 61 21  0
#  36]
#
# Unique values in PhoneService are: [1 0]
#
# Unique values in MultipleLines are: [1 0 2]
#
# Unique values in InternetService are: [0 1 2]
#
# Unique values in OnlineSecurity are: [2 0 1]
#
# Unique values in OnlineBackup are: [2 1 0]
#
# Unique values in DeviceProtection are: [2 1 0]
#
# Unique values in TechSupport are: [2 0 1]
#
# Unique values in StreamingTV are: [2 1 0]
#
# Unique values in StreamingMovies are: [2 0 1]
#
# Unique values in Contract are: [24  1 12]
#
# Unique values in PaperlessBilling are: [0 1]
#
# ...

# %%
x.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges         object
# Churn                 int64
# dtype: object

# %%
x['TotalCharges'] = x['TotalCharges'].replace(' ', 0)
x['TotalCharges'] = x['TotalCharges'].astype(float)

# %%
x.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
x.head(3)
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           1      72             1
# 1       0              0        0           0      44             1
# 2       0              1        1           0      38             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               2             2
# 1              0                1               0             1
# 2              1                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 2            2            2                2        24
# 1                 1            0            1                0         1
# 2                 0            0            0                0         1
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# ...

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          1              0        1           1      72             1
# 1          0              0        0           0      44             1
# 2          0              1        1           0      38             1
# 3          1              0        0           0       4             1
# 4          1              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 5981       1              0        1           0       1             1
# 5982       0              0        1           1      23             1
# 5983       1              0        1           1      12             1
# 5984       1              1        0           0      12             1
# 5985       1              0        0           0      26             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
plt.figure(figsize= (15,10))
sns.heatmap(x.corr(), cmap= 'Blues', annot= True, linewidths= 1)
plt.title('Correlation Matrix', fontsize= 16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
